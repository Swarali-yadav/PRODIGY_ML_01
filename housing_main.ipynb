# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pip install sns

# %%
data=pd.read_csv('housing.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
x=data.drop(['median_house_value'],axis=1)

# %%
x.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income ocean_proximity
# 0       322.0       126.0         8.3252        NEAR BAY
# 1      2401.0      1138.0         8.3014        NEAR BAY

# %%
y=data['median_house_value']

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
train_data=x_train.join(y_train)

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20281    -119.19     34.18                32.0       3366.0           677.0
# 15507    -117.08     33.14                15.0       1497.0           250.0
# 13266    -117.68     34.09                22.0       1547.0           334.0
# 7289     -118.22     33.98                32.0       2643.0           737.0
# 2706     -115.60     32.87                 3.0       1629.0           317.0
#
#        population  households  median_income ocean_proximity  \
# 20281      2857.0       669.0         4.6186      NEAR OCEAN
# 15507       827.0       239.0         4.3846       <1H OCEAN
# 13266       773.0       316.0         2.9812          INLAND
# 7289       2784.0       711.0         2.5352       <1H OCEAN
# 2706       1005.0       312.0         4.1293          INLAND
#
#        median_house_value
# 20281            181100.0
# 15507            154200.0
# 13266            148800.0
# 7289             184400.0
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
numeric_columns = train_data.select_dtypes(include=['float', 'int'])
sns.heatmap(numeric_columns.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7235
# INLAND        5243
# NEAR OCEAN    2102
# NEAR BAY      1762
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity, prefix='ocean_proximity', dtype=int)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20281    -119.19     34.18                32.0     8.121777        6.519147
# 15507    -117.08     33.14                15.0     7.311886        5.525453
# 13266    -117.68     34.09                22.0     7.344719        5.814131
# 7289     -118.22     33.98                32.0     7.880048        6.603944
# 2706     -115.60     32.87                 3.0     7.396335        5.762051
# ...          ...       ...                 ...          ...             ...
# 6778     -118.17     34.12                37.0     7.717351        6.177944
# 12844    -121.37     38.68                34.0     6.991177        5.236442
# 8353     -118.32     33.95                44.0     7.612831        5.786897
# 7904     -118.06     33.85                16.0     8.487146        6.588926
# 4755     -118.33     34.04                52.0     7.842279        5.996452
#
# ...

# %%
numeric_columns = train_data.select_dtypes(include=['float', 'int'])
plt.figure(figsize=(10, 8)) 
sns.heatmap(numeric_columns.corr(), annot=True, cmap="YlGnBu", fmt=".2f", linewidths=.5, annot_kws={"size": 10})
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"]=train_data["total_bedrooms"]/train_data["total_rooms"]
train_data["household_rooms"]=train_data["total_rooms"]/train_data["households"]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20281    -119.19     34.18                32.0     8.121777        6.519147
# 15507    -117.08     33.14                15.0     7.311886        5.525453
# 13266    -117.68     34.09                22.0     7.344719        5.814131
# 7289     -118.22     33.98                32.0     7.880048        6.603944
# 2706     -115.60     32.87                 3.0     7.396335        5.762051
# ...          ...       ...                 ...          ...             ...
# 6778     -118.17     34.12                37.0     7.717351        6.177944
# 12844    -121.37     38.68                34.0     6.991177        5.236442
# 8353     -118.32     33.95                44.0     7.612831        5.786897
# 7904     -118.06     33.85                16.0     8.487146        6.588926
# 4755     -118.33     34.04                52.0     7.842279        5.996452
#
# ...

# %%
plt.figure(figsize=(10, 8)) 
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu", fmt=".2f", linewidths=.5, annot_kws={"size": 10})
plt.show()

# %%
# train_data=x_train.join(y_train)

# train_data['total_rooms']=np.log(train_data['total_rooms']+1)
# train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
# train_data['population']=np.log(train_data['population']+1)
# train_data['households']=np.log(train_data['households']+1)

# train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity, prefix='ocean_proximity', dtype=int)).drop(['ocean_proximity'], axis=1)

# train_data["bedroom_ratio"]=train_data["total_bedrooms"]/train_data["total_rooms"]
# train_data["household_rooms"]=train_data["total_rooms"]/train_data["households"]

# %%
#LINEAR REGREESION MODEL
from sklearn.linear_model import LinearRegression
x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data[('median_house_value')]
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data=x_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity, prefix='ocean_proximity', dtype=int)).drop(['ocean_proximity'], axis=1)

test_data["bedroom_ratio"]=test_data["total_bedrooms"]/test_data["total_rooms"]
test_data["household_rooms"]=test_data["total_rooms"]/test_data["households"]

x_test,y_test=test_data.drop(['median_house_value'],axis=1),test_data[('median_house_value')]

# %%
x_test.head(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16178    -122.40     37.71                47.0     7.408531        5.796058
# 19416    -121.08     37.69                19.0     8.775549        7.100852
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 16178    7.076654    5.877736         3.3625                          0
# 19416    8.177516    7.024649         3.2246                          0
#
#        ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 16178                       0                       0
# 19416                       1                       0
#
#        ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN  bedroom_ratio  \
# 16178                         1                           0       0.782349
# 19416                         0                           0       0.809163
#
#        household_rooms
# 16178         1.260440
# 19416         1.249251

# %%
reg.score(x_test,y_test)
# Out:
# 0.6832810426818843

# %%
#random forest
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.8157361929575593

# %%
#grid_search
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
    "n_estimators":[3,10,30],
    "max_features":[2,4,6,8]
}

# %%
grid_search=GridSearchCV(forest,param_grid,cv=5,scoring="neg_mean_squared_error",return_train_score=True)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=8, n_estimators=30)

# %%
grid_search.best_estimator_.score(x_test,y_test)
# Out:
# 0.8152102400958765
